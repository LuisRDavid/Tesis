# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('../Other_files/curvaCalibracionA.csv')
df.head()
# Out:
#    CONCENTRACION   ABSORBANCIA
# 0              0        -0.075
# 1             20        -0.021
# 2             50        -0.013
# 3            100         0.004
# 4            200         0.062

# %%
yVal = df['CONCENTRACION']
yVal
# Out:
# 0       0
# 1      20
# 2      50
# 3     100
# 4     200
# 5     500
# 6    1000
# Name: CONCENTRACION, dtype: int64

# %%
xVal = df[' ABSORBANCIA']
xVal
# Out:
# 0   -0.075
# 1   -0.021
# 2   -0.013
# 3    0.004
# 4    0.062
# 5    0.139
# 6    0.271
# Name:  ABSORBANCIA, dtype: float64

# %%
fig = plt.figure()
ax = fig.subplots()
plt.scatter(xVal, yVal, edgecolors='black')
plt.plot(xVal, yVal, label='DQO')
plt.plot(absorbance, concentration_pred, color='r')
ax.text(0.10, 200, r'$R^2= %0.4f$' %(R2))
ax.text(0.10, 260, label)
plt.grid()
plt.legend()

# %%
concentration = df['CONCENTRACION'].values.reshape(-1,1)
absorbance = df[' ABSORBANCIA'].values.reshape(-1,1)
linearRegressor = LinearRegression()
linearRegressor.fit(absorbance, concentration)
concentration_pred = linearRegressor.predict(absorbance)
concentration_pred
# Out:
# array([[-120.23512327],
#        [  43.92281013],
#        [  68.24250397],
#        [ 119.92185338],
#        [ 296.2396337 ],
#        [ 530.31668688],
#        [ 931.5916352 ]])

# %%
m = linearRegressor.coef_[0][0]
c = linearRegressor.intercept_[0]
label = r'$DQO= %0.4f*X %+0.4f$' %(m,c)
print(label)
# Out:
# $DQO= 3039.9617*X +107.7620$

# %%
from sklearn.metrics import r2_score
R2 = r2_score(concentration, concentration_pred)
print(R2)
# Out:
# 0.9618851059603185
