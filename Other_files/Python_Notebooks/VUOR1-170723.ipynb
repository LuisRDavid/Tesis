# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

df = pd.read_csv('../VUO-170723.csv')
time = df['TIEMPO'].values.reshape(-1,1)
od = df['OD_R1'].values.reshape(-1,1)

linearRegressor = LinearRegression()
linearRegressor.fit(time, od)
odPredict = linearRegressor.predict(time)
odPredict
m = linearRegressor.coef_[0][0]
c = linearRegressor.intercept_[0]
label = r'$VUO= %0.4fx %+0.4f$' % (m, c)
print(label)
R2 = r2_score(time, odPredict)
print(R2)

fig = plt.figure()
ax = fig.subplots()
plt.plot(time, od)
plt.plot(time, odPredict)
plt.grid(visible=True)
ax.text(2.5, 2, label)
ax.text(2.5, 1.8, r'$R^2= %0.4f$'%(R2))
# Out:
# $VUO= -0.2283x +4.9477$
# -1.9764326149434974
# Text(2.5, 1.8, '$R^2= -1.9764$')
