# %% [markdown]
# ### VUO Reactor 1

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('../VUO-030823.csv')
time = df['TIEMPO'].values.reshape(-1,1)
od = df['OD_R1'].values.reshape(-1,1)

# %%
linearRegressor = LinearRegression()
linearRegressor.fit(time[1:], od[1:])
odPredict = linearRegressor.predict(time[1:])
odPredict
m = linearRegressor.coef_[0][0]
c = linearRegressor.intercept_[0]
label = r'$VUO= %0.4fx %+0.4f$' % (m, c)
print(label)
R2 = r2_score(time[1:], odPredict)
print(R2)
# Out:
# $VUO= -0.1837x +4.9133$
# -2.1002057796370623

# %%
fig = plt.figure()
ax = fig.subplots()
plt.plot(time[1:], od[1:])
plt.plot(time[1:], odPredict)
plt.grid(visible=True)
ax.text(2.5, 2.5, label)
ax.text(2.5, 2.3, r'$R^2= %0.4f$'%(R2))
# Out:
# Text(2.5, 2.3, '$R^2= -2.1002$')
